# %% [markdown]
# # Hello World!
#
# Here's an example notebook with some documentation on how to access CMIP data.

# %%
# %matplotlib inline

import xarray as xr
import intake

# util.py is in the local directory
# it contains code that is common across project notebooks
# or routines that are too extensive and might otherwise clutter
# the notebook design
import util
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/intake/source/discovery.py:136: FutureWarning: The drivers ['stac-catalog', 'stac-collection', 'stac-item'] do not specify entry_points and were only discovered via a package scan. This may break in a future release of intake. The packages should be updated.
#   FutureWarning)

# %%
print('hello world!')
# Out:
# hello world!

# %% [markdown]
# ## Demonstrate how to use `intake-esm`
# [Intake-esm](https://intake-esm.readthedocs.io) is a data cataloging utility that facilitates access to CMIP data. It's pretty awesome.
#
# An `intake-esm` collection object establishes a link to a database that contains file locations and associated metadata (i.e., which experiement, model, the come from).
#
# ### Opening a collection
# First step is to open the collection by pointing the collection definition file, which is a JSON file that conforms to the [ESM Collection Specification](https://github.com/NCAR/esm-collection-spec).
#
# The collection JSON files are stored locally in this repository for purposes of reproducibility---and because Cheyenne compute nodes don't have Internet access.
#
# The primary source for these files is the [intake-esm-datastore](https://github.com/NCAR/intake-esm-datastore) repository. Any changes made to these files should be pulled from that repo. For instance, the Pangeo cloud collection is available [here](https://raw.githubusercontent.com/NCAR/intake-esm-datastore/master/catalogs/pangeo-cmip6.json).

# %%
if util.is_ncar_host():
    col = intake.open_esm_datastore("../catalogs/glade-cmip6.json")
else:
    col = intake.open_esm_datastore("../catalogs/pangeo-cmip6.json")
col
# Out:
# pangeo-cmip6-ESM Collection with 28660 entries:
# 	> 10 activity_id(s)
#
# 	> 23 institution_id(s)
#
# 	> 48 source_id(s)
#
# 	> 29 experiment_id(s)
#
# 	> 86 member_id(s)
#
# 	> 23 table_id(s)
#
# 	> 190 variable_id(s)
#
# 	> 7 grid_label(s)
#
# 	> 28660 zstore(s)
#
# 	> 59 dcpp_init_year(s)

# %% [markdown]
# `intake-esm` is build on top of [pandas](https://pandas.pydata.org/pandas-docs/stable). It is possible to view the `pandas.DataFrame` as follows.

# %%
col.df.head()
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 1  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 2  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 3  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 4  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
#
#   variable_id grid_label                                             zstore  \
# 0          pr         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 1        prsn         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 2         tas         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 3      tasmax         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 4      tasmin         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
#
#    dcpp_init_year
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %% [markdown]
# It is possible to interact with the `DataFrame`; for instance, we can see what the "attributes" of the datasets are by printing the columns.

# %%
col.df.columns
# Out:
# Index(['activity_id', 'institution_id', 'source_id', 'experiment_id',
#        'member_id', 'table_id', 'variable_id', 'grid_label', 'zstore',
#        'dcpp_init_year'],
#       dtype='object')

# %% [markdown]
# ### Search and discovery
#
# #### Finding unique entries
# Let's query the data to see what models ("source_id"), experiments ("experiment_id") and temporal frequencies ("table_id") are available.

# %%
import pprint 
uni_dict = col.unique(['source_id', 'experiment_id', 'table_id'])
pprint.pprint(uni_dict, compact=True)
# Out:
# {'experiment_id': {'count': 29,
#                    'values': ['ssp370', 'esm-ssp585', '1pctCO2-bgc', 'hist-bgc',
#                               '1pctCO2', 'abrupt-4xCO2', 'historical',
#                               'piControl', 'amip', 'esm-hist', 'esm-piControl',
#                               'hist-GHG', 'hist-aer', 'hist-nat', 'dcppA-assim',
#                               'dcppA-hindcast', 'dcppC-hindcast-noAgung',
#                               'dcppC-hindcast-noElChichon',
#                               'dcppC-hindcast-noPinatubo', 'highresSST-present',
#                               'control-1950', 'hist-1950', 'deforest-globe',
#                               'esm-ssp585-ssp126Lu', 'omip1', 'lgm', 'ssp126',
#                               'ssp245', 'ssp585']},
#  'source_id': {'count': 48,
#                'values': ['BCC-ESM1', 'BCC-CSM2-MR', 'CanESM5', 'CNRM-ESM2-1',
#                           'UKESM1-0-LL', 'GISS-E2-1-G', 'CESM2', 'GFDL-ESM4',
#                           'AWI-CM-1-1-MR', 'CAMS-CSM1-0', 'FGOALS-f3-L',
#                           'FGOALS-g3', 'CNRM-CM6-1', 'E3SM-1-0', 'EC-Earth3-LR',
#                           'EC-Earth3-Veg', 'EC-Earth3', 'FIO-ESM-2-0',
#                           'IPSL-CM6A-LR', 'MIROC-ES2L', 'MIROC6',
#                           'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM', 'MRI-ESM2-0',
#                           'GISS-E2-1-G-CC', 'GISS-E2-1-H', 'CESM2-WACCM',
#                           'NorCPM1', 'GFDL-AM4', 'GFDL-CM4', 'NESM3',
#                           'SAM0-UNICON', 'MCM-UA-1-0', 'CMCC-CM2-HR4',
#                           'CMCC-CM2-VHR4', 'CNRM-CM6-1-HR', 'ECMWF-IFS-HR',
#                           'ECMWF-IFS-LR', 'IPSL-CM6A-ATM-HR', 'NICAM16-7S',
#                           'NICAM16-8S', 'NICAM16-9S', 'HadGEM3-GC31-HM',
#                           'HadGEM3-GC31-LM', 'MRI-AGCM3-2-H', 'MRI-AGCM3-2-S',
#                           'GFDL-CM4C192', 'MPI-ESM1-2-HR']},
#  'table_id': {'count': 23,
#               'values': ['Amon', 'Lmon', 'Oyr', 'Omon', 'SImon', 'day', '3hr',
#                          '6hrLev', 'LImon', 'Aclim', 'Ofx', 'fx', 'Emon',
#                          '6hrPlev', 'Oclim', 'SIclim', 'Eclim', 'Odec',
#                          'AERmon', 'ImonGre', '6hrPlevPt', 'CF3hr', 'E3hr']}}

# %% [markdown]
# #### Searching for specific datasets
#
# Let's find all the dissolved oxygen data at annual frequency from the ocean for the `historical` and `ssp585` experiments.

# %%
cat = col.search(experiment_id=['historical', 'ssp585'], table_id='Oyr', variable_id='o2', grid_label='gn')
cat.df
# Out:
#        activity_id institution_id      source_id experiment_id  member_id  \
# 1480          CMIP          CCCma        CanESM5    historical  r10i1p1f1
# 1549          CMIP          CCCma        CanESM5    historical  r10i1p2f1
# 1619          CMIP          CCCma        CanESM5    historical  r11i1p1f1
# 1715          CMIP          CCCma        CanESM5    historical  r12i1p1f1
# 1811          CMIP          CCCma        CanESM5    historical  r13i1p1f1
# 1908          CMIP          CCCma        CanESM5    historical  r14i1p1f1
# 2004          CMIP          CCCma        CanESM5    historical  r15i1p1f1
# 2100          CMIP          CCCma        CanESM5    historical  r16i1p1f1
# 2196          CMIP          CCCma        CanESM5    historical  r17i1p1f1
# 2293          CMIP          CCCma        CanESM5    historical  r18i1p1f1
# 2390          CMIP          CCCma        CanESM5    historical  r19i1p1f1
# 2486          CMIP          CCCma        CanESM5    historical   r1i1p1f1
# 2554          CMIP          CCCma        CanESM5    historical   r1i1p2f1
# 2625          CMIP          CCCma        CanESM5    historical  r20i1p1f1
# 2721          CMIP          CCCma        CanESM5    historical  r21i1p1f1
# 2818          CMIP          CCCma        CanESM5    historical  r22i1p1f1
# 2916          CMIP          CCCma        CanESM5    historical  r23i1p1f1
# 3012          CMIP          CCCma        CanESM5    historical  r24i1p1f1
# 3109          CMIP          CCCma        CanESM5    historical  r25i1p1f1
# 3205          CMIP          CCCma        CanESM5    historical   r2i1p1f1
# 3275          CMIP          CCCma        CanESM5    historical   r2i1p2f1
# 3345          CMIP          CCCma        CanESM5    historical   r3i1p1f1
# 3413          CMIP          CCCma        CanESM5    historical   r3i1p2f1
# 3484          CMIP          CCCma        CanESM5    historical   r4i1p1f1
# 3552          CMIP          CCCma        CanESM5    historical   r4i1p2f1
# 3622          CMIP          CCCma        CanESM5    historical   r5i1p1f1
# 3679          CMIP          CCCma        CanESM5    historical   r5i1p2f1
# 3750          CMIP          CCCma        CanESM5    historical   r6i1p1f1
# 3818          CMIP          CCCma        CanESM5    historical   r6i1p2f1
# 3889          CMIP          CCCma        CanESM5    historical   r7i1p1f1
# ...            ...            ...            ...           ...        ...
# 9262          CMIP          MIROC     MIROC-ES2L    historical   r1i1p1f2
# 9330          CMIP          MIROC     MIROC-ES2L    historical   r2i1p1f2
# 9398          CMIP          MIROC     MIROC-ES2L    historical   r3i1p1f2
# 13431         CMIP           NCAR    CESM2-WACCM    historical   r1i1p1f1
# 13551         CMIP           NCAR    CESM2-WACCM    historical   r2i1p1f1
# 13660         CMIP           NCAR    CESM2-WACCM    historical   r3i1p1f1
# 22237  ScenarioMIP          CCCma        CanESM5        ssp585  r10i1p1f1
# 22313  ScenarioMIP          CCCma        CanESM5        ssp585  r10i1p2f1
# 22737  ScenarioMIP          CCCma        CanESM5        ssp585   r1i1p1f1
# 22800  ScenarioMIP          CCCma        CanESM5        ssp585   r1i1p2f1
# 23103  ScenarioMIP          CCCma        CanESM5        ssp585   r2i1p1f1
# 23165  ScenarioMIP          CCCma        CanESM5        ssp585   r2i1p2f1
# 23228  ScenarioMIP          CCCma        CanESM5        ssp585   r3i1p1f1
# 23290  ScenarioMIP          CCCma        CanESM5        ssp585   r3i1p2f1
# 23353  ScenarioMIP          CCCma        CanESM5        ssp585   r4i1p1f1
# 23415  ScenarioMIP          CCCma        CanESM5        ssp585   r4i1p2f1
# 23479  ScenarioMIP          CCCma        CanESM5        ssp585   r5i1p1f1
# 23542  ScenarioMIP          CCCma        CanESM5        ssp585   r5i1p2f1
# 23606  ScenarioMIP          CCCma        CanESM5        ssp585   r6i1p1f1
# 23668  ScenarioMIP          CCCma        CanESM5        ssp585   r6i1p2f1
# 23732  ScenarioMIP          CCCma        CanESM5        ssp585   r7i1p1f1
# 23794  ScenarioMIP          CCCma        CanESM5        ssp585   r7i1p2f1
# 23857  ScenarioMIP          CCCma        CanESM5        ssp585   r8i1p1f1
# 23920  ScenarioMIP          CCCma        CanESM5        ssp585   r8i1p2f1
# 23984  ScenarioMIP          CCCma        CanESM5        ssp585   r9i1p1f1
# 24047  ScenarioMIP          CCCma        CanESM5        ssp585   r9i1p2f1
# 25727  ScenarioMIP           DKRZ  MPI-ESM1-2-HR        ssp585   r1i1p1f1
# 26201  ScenarioMIP           IPSL   IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26377  ScenarioMIP          MIROC     MIROC-ES2L        ssp585   r1i1p1f2
# 28380  ScenarioMIP           NCAR          CESM2        ssp585   r2i1p1f1
#
#       table_id variable_id grid_label  \
# 1480       Oyr          o2         gn
# 1549       Oyr          o2         gn
# 1619       Oyr          o2         gn
# 1715       Oyr          o2         gn
# 1811       Oyr          o2         gn
# 1908       Oyr          o2         gn
# 2004       Oyr          o2         gn
# 2100       Oyr          o2         gn
# 2196       Oyr          o2         gn
# 2293       Oyr          o2         gn
# 2390       Oyr          o2         gn
# 2486       Oyr          o2         gn
# 2554       Oyr          o2         gn
# 2625       Oyr          o2         gn
# 2721       Oyr          o2         gn
# 2818       Oyr          o2         gn
# 2916       Oyr          o2         gn
# 3012       Oyr          o2         gn
# 3109       Oyr          o2         gn
# 3205       Oyr          o2         gn
# 3275       Oyr          o2         gn
# 3345       Oyr          o2         gn
# 3413       Oyr          o2         gn
# 3484       Oyr          o2         gn
# 3552       Oyr          o2         gn
# 3622       Oyr          o2         gn
# 3679       Oyr          o2         gn
# 3750       Oyr          o2         gn
# 3818       Oyr          o2         gn
# 3889       Oyr          o2         gn
# ...        ...         ...        ...
# 9262       Oyr          o2         gn
# 9330       Oyr          o2         gn
# 9398       Oyr          o2         gn
# 13431      Oyr          o2         gn
# 13551      Oyr          o2         gn
# 13660      Oyr          o2         gn
# 22237      Oyr          o2         gn
# 22313      Oyr          o2         gn
# 22737      Oyr          o2         gn
# 22800      Oyr          o2         gn
# 23103      Oyr          o2         gn
# 23165      Oyr          o2         gn
# 23228      Oyr          o2         gn
# 23290      Oyr          o2         gn
# 23353      Oyr          o2         gn
# 23415      Oyr          o2         gn
# 23479      Oyr          o2         gn
# 23542      Oyr          o2         gn
# 23606      Oyr          o2         gn
# 23668      Oyr          o2         gn
# 23732      Oyr          o2         gn
# 23794      Oyr          o2         gn
# 23857      Oyr          o2         gn
# 23920      Oyr          o2         gn
# 23984      Oyr          o2         gn
# 24047      Oyr          o2         gn
# 25727      Oyr          o2         gn
# 26201      Oyr          o2         gn
# 26377      Oyr          o2         gn
# 28380      Oyr          o2         gn
#
#                                                   zstore  dcpp_init_year
# 1480   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1549   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1619   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1715   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1811   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1908   gs://cmip6/CMIP/CCCma/CanESM5/historical/r14i1...             NaN
# 2004   gs://cmip6/CMIP/CCCma/CanESM5/historical/r15i1...             NaN
# 2100   gs://cmip6/CMIP/CCCma/CanESM5/historical/r16i1...             NaN
# 2196   gs://cmip6/CMIP/CCCma/CanESM5/historical/r17i1...             NaN
# 2293   gs://cmip6/CMIP/CCCma/CanESM5/historical/r18i1...             NaN
# 2390   gs://cmip6/CMIP/CCCma/CanESM5/historical/r19i1...             NaN
# 2486   gs://cmip6/CMIP/CCCma/CanESM5/historical/r1i1p...             NaN
# 2554   gs://cmip6/CMIP/CCCma/CanESM5/historical/r1i1p...             NaN
# 2625   gs://cmip6/CMIP/CCCma/CanESM5/historical/r20i1...             NaN
# 2721   gs://cmip6/CMIP/CCCma/CanESM5/historical/r21i1...             NaN
# 2818   gs://cmip6/CMIP/CCCma/CanESM5/historical/r22i1...             NaN
# 2916   gs://cmip6/CMIP/CCCma/CanESM5/historical/r23i1...             NaN
# 3012   gs://cmip6/CMIP/CCCma/CanESM5/historical/r24i1...             NaN
# 3109   gs://cmip6/CMIP/CCCma/CanESM5/historical/r25i1...             NaN
# 3205   gs://cmip6/CMIP/CCCma/CanESM5/historical/r2i1p...             NaN
# 3275   gs://cmip6/CMIP/CCCma/CanESM5/historical/r2i1p...             NaN
# 3345   gs://cmip6/CMIP/CCCma/CanESM5/historical/r3i1p...             NaN
# 3413   gs://cmip6/CMIP/CCCma/CanESM5/historical/r3i1p...             NaN
# 3484   gs://cmip6/CMIP/CCCma/CanESM5/historical/r4i1p...             NaN
# 3552   gs://cmip6/CMIP/CCCma/CanESM5/historical/r4i1p...             NaN
# 3622   gs://cmip6/CMIP/CCCma/CanESM5/historical/r5i1p...             NaN
# 3679   gs://cmip6/CMIP/CCCma/CanESM5/historical/r5i1p...             NaN
# 3750   gs://cmip6/CMIP/CCCma/CanESM5/historical/r6i1p...             NaN
# 3818   gs://cmip6/CMIP/CCCma/CanESM5/historical/r6i1p...             NaN
# 3889   gs://cmip6/CMIP/CCCma/CanESM5/historical/r7i1p...             NaN
# ...                                                  ...             ...
# 9262   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r1...             NaN
# 9330   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r2...             NaN
# 9398   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r3...             NaN
# 13431  gs://cmip6/CMIP/NCAR/CESM2-WACCM/historical/r1...             NaN
# 13551  gs://cmip6/CMIP/NCAR/CESM2-WACCM/historical/r2...             NaN
# 13660  gs://cmip6/CMIP/NCAR/CESM2-WACCM/historical/r3...             NaN
# 22237  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22313  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22737  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22800  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 23103  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r2...             NaN
# 23165  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r2...             NaN
# 23228  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r3...             NaN
# 23290  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r3...             NaN
# 23353  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r4...             NaN
# 23415  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r4...             NaN
# 23479  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r5...             NaN
# 23542  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r5...             NaN
# 23606  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23668  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23732  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23794  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23857  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23920  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23984  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24047  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 25727  gs://cmip6/ScenarioMIP/DKRZ/MPI-ESM1-2-HR/ssp5...             NaN
# 26201  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26377  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 28380  gs://cmip6/ScenarioMIP/NCAR/CESM2/ssp585/r2i1p...             NaN
#
# [97 rows x 10 columns]

# %% [markdown]
# It might be desirable to get more specific. For instance, we may want to select only the models that have *both* `historical` and `ssp585` data. We coud do this as follows.

# %%
models = set(uni_dict['source_id']['values']) # all the models

for experiment_id in ['historical', 'ssp585']:
    query = dict(experiment_id=experiment_id, table_id='Oyr', 
                 variable_id='o2', grid_label='gn')  
    cat = col.search(**query)
    models = models.intersection({model for model in cat.df.source_id.unique().tolist()})

# ensure the CESM2 models are not included (oxygen was erroneously submitted to the archive)
models = models - {'CESM2-WACCM', 'CESM2'}

models = list(models)
models
# Out:
# ['CanESM5', 'MIROC-ES2L', 'IPSL-CM6A-LR']

# %%
cat = col.search(experiment_id=['historical', 'ssp585'], table_id='Oyr', 
                 variable_id='o2', grid_label='gn', source_id=models)
cat.df
# Out:
#        activity_id institution_id     source_id experiment_id  member_id  \
# 1480          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1549          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1619          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1715          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1811          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1908          CMIP          CCCma       CanESM5    historical  r14i1p1f1
# 2004          CMIP          CCCma       CanESM5    historical  r15i1p1f1
# 2100          CMIP          CCCma       CanESM5    historical  r16i1p1f1
# 2196          CMIP          CCCma       CanESM5    historical  r17i1p1f1
# 2293          CMIP          CCCma       CanESM5    historical  r18i1p1f1
# 2390          CMIP          CCCma       CanESM5    historical  r19i1p1f1
# 2486          CMIP          CCCma       CanESM5    historical   r1i1p1f1
# 2554          CMIP          CCCma       CanESM5    historical   r1i1p2f1
# 2625          CMIP          CCCma       CanESM5    historical  r20i1p1f1
# 2721          CMIP          CCCma       CanESM5    historical  r21i1p1f1
# 2818          CMIP          CCCma       CanESM5    historical  r22i1p1f1
# 2916          CMIP          CCCma       CanESM5    historical  r23i1p1f1
# 3012          CMIP          CCCma       CanESM5    historical  r24i1p1f1
# 3109          CMIP          CCCma       CanESM5    historical  r25i1p1f1
# 3205          CMIP          CCCma       CanESM5    historical   r2i1p1f1
# 3275          CMIP          CCCma       CanESM5    historical   r2i1p2f1
# 3345          CMIP          CCCma       CanESM5    historical   r3i1p1f1
# 3413          CMIP          CCCma       CanESM5    historical   r3i1p2f1
# 3484          CMIP          CCCma       CanESM5    historical   r4i1p1f1
# 3552          CMIP          CCCma       CanESM5    historical   r4i1p2f1
# 3622          CMIP          CCCma       CanESM5    historical   r5i1p1f1
# 3679          CMIP          CCCma       CanESM5    historical   r5i1p2f1
# 3750          CMIP          CCCma       CanESM5    historical   r6i1p1f1
# 3818          CMIP          CCCma       CanESM5    historical   r6i1p2f1
# 3889          CMIP          CCCma       CanESM5    historical   r7i1p1f1
# ...            ...            ...           ...           ...        ...
# 8713          CMIP           IPSL  IPSL-CM6A-LR    historical   r5i1p1f1
# 8793          CMIP           IPSL  IPSL-CM6A-LR    historical   r6i1p1f1
# 8873          CMIP           IPSL  IPSL-CM6A-LR    historical   r7i1p1f1
# 8953          CMIP           IPSL  IPSL-CM6A-LR    historical   r8i1p1f1
# 9033          CMIP           IPSL  IPSL-CM6A-LR    historical   r9i1p1f1
# 9262          CMIP          MIROC    MIROC-ES2L    historical   r1i1p1f2
# 9330          CMIP          MIROC    MIROC-ES2L    historical   r2i1p1f2
# 9398          CMIP          MIROC    MIROC-ES2L    historical   r3i1p1f2
# 22237  ScenarioMIP          CCCma       CanESM5        ssp585  r10i1p1f1
# 22313  ScenarioMIP          CCCma       CanESM5        ssp585  r10i1p2f1
# 22737  ScenarioMIP          CCCma       CanESM5        ssp585   r1i1p1f1
# 22800  ScenarioMIP          CCCma       CanESM5        ssp585   r1i1p2f1
# 23103  ScenarioMIP          CCCma       CanESM5        ssp585   r2i1p1f1
# 23165  ScenarioMIP          CCCma       CanESM5        ssp585   r2i1p2f1
# 23228  ScenarioMIP          CCCma       CanESM5        ssp585   r3i1p1f1
# 23290  ScenarioMIP          CCCma       CanESM5        ssp585   r3i1p2f1
# 23353  ScenarioMIP          CCCma       CanESM5        ssp585   r4i1p1f1
# 23415  ScenarioMIP          CCCma       CanESM5        ssp585   r4i1p2f1
# 23479  ScenarioMIP          CCCma       CanESM5        ssp585   r5i1p1f1
# 23542  ScenarioMIP          CCCma       CanESM5        ssp585   r5i1p2f1
# 23606  ScenarioMIP          CCCma       CanESM5        ssp585   r6i1p1f1
# 23668  ScenarioMIP          CCCma       CanESM5        ssp585   r6i1p2f1
# 23732  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23794  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23857  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23920  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23984  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 24047  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 26201  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26377  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
#
#       table_id variable_id grid_label  \
# 1480       Oyr          o2         gn
# 1549       Oyr          o2         gn
# 1619       Oyr          o2         gn
# 1715       Oyr          o2         gn
# 1811       Oyr          o2         gn
# 1908       Oyr          o2         gn
# 2004       Oyr          o2         gn
# 2100       Oyr          o2         gn
# 2196       Oyr          o2         gn
# 2293       Oyr          o2         gn
# 2390       Oyr          o2         gn
# 2486       Oyr          o2         gn
# 2554       Oyr          o2         gn
# 2625       Oyr          o2         gn
# 2721       Oyr          o2         gn
# 2818       Oyr          o2         gn
# 2916       Oyr          o2         gn
# 3012       Oyr          o2         gn
# 3109       Oyr          o2         gn
# 3205       Oyr          o2         gn
# 3275       Oyr          o2         gn
# 3345       Oyr          o2         gn
# 3413       Oyr          o2         gn
# 3484       Oyr          o2         gn
# 3552       Oyr          o2         gn
# 3622       Oyr          o2         gn
# 3679       Oyr          o2         gn
# 3750       Oyr          o2         gn
# 3818       Oyr          o2         gn
# 3889       Oyr          o2         gn
# ...        ...         ...        ...
# 8713       Oyr          o2         gn
# 8793       Oyr          o2         gn
# 8873       Oyr          o2         gn
# 8953       Oyr          o2         gn
# 9033       Oyr          o2         gn
# 9262       Oyr          o2         gn
# 9330       Oyr          o2         gn
# 9398       Oyr          o2         gn
# 22237      Oyr          o2         gn
# 22313      Oyr          o2         gn
# 22737      Oyr          o2         gn
# 22800      Oyr          o2         gn
# 23103      Oyr          o2         gn
# 23165      Oyr          o2         gn
# 23228      Oyr          o2         gn
# 23290      Oyr          o2         gn
# 23353      Oyr          o2         gn
# 23415      Oyr          o2         gn
# 23479      Oyr          o2         gn
# 23542      Oyr          o2         gn
# 23606      Oyr          o2         gn
# 23668      Oyr          o2         gn
# 23732      Oyr          o2         gn
# 23794      Oyr          o2         gn
# 23857      Oyr          o2         gn
# 23920      Oyr          o2         gn
# 23984      Oyr          o2         gn
# 24047      Oyr          o2         gn
# 26201      Oyr          o2         gn
# 26377      Oyr          o2         gn
#
#                                                   zstore  dcpp_init_year
# 1480   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1549   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1619   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1715   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1811   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1908   gs://cmip6/CMIP/CCCma/CanESM5/historical/r14i1...             NaN
# 2004   gs://cmip6/CMIP/CCCma/CanESM5/historical/r15i1...             NaN
# 2100   gs://cmip6/CMIP/CCCma/CanESM5/historical/r16i1...             NaN
# 2196   gs://cmip6/CMIP/CCCma/CanESM5/historical/r17i1...             NaN
# 2293   gs://cmip6/CMIP/CCCma/CanESM5/historical/r18i1...             NaN
# 2390   gs://cmip6/CMIP/CCCma/CanESM5/historical/r19i1...             NaN
# 2486   gs://cmip6/CMIP/CCCma/CanESM5/historical/r1i1p...             NaN
# 2554   gs://cmip6/CMIP/CCCma/CanESM5/historical/r1i1p...             NaN
# 2625   gs://cmip6/CMIP/CCCma/CanESM5/historical/r20i1...             NaN
# 2721   gs://cmip6/CMIP/CCCma/CanESM5/historical/r21i1...             NaN
# 2818   gs://cmip6/CMIP/CCCma/CanESM5/historical/r22i1...             NaN
# 2916   gs://cmip6/CMIP/CCCma/CanESM5/historical/r23i1...             NaN
# 3012   gs://cmip6/CMIP/CCCma/CanESM5/historical/r24i1...             NaN
# 3109   gs://cmip6/CMIP/CCCma/CanESM5/historical/r25i1...             NaN
# 3205   gs://cmip6/CMIP/CCCma/CanESM5/historical/r2i1p...             NaN
# 3275   gs://cmip6/CMIP/CCCma/CanESM5/historical/r2i1p...             NaN
# 3345   gs://cmip6/CMIP/CCCma/CanESM5/historical/r3i1p...             NaN
# 3413   gs://cmip6/CMIP/CCCma/CanESM5/historical/r3i1p...             NaN
# 3484   gs://cmip6/CMIP/CCCma/CanESM5/historical/r4i1p...             NaN
# 3552   gs://cmip6/CMIP/CCCma/CanESM5/historical/r4i1p...             NaN
# 3622   gs://cmip6/CMIP/CCCma/CanESM5/historical/r5i1p...             NaN
# 3679   gs://cmip6/CMIP/CCCma/CanESM5/historical/r5i1p...             NaN
# 3750   gs://cmip6/CMIP/CCCma/CanESM5/historical/r6i1p...             NaN
# 3818   gs://cmip6/CMIP/CCCma/CanESM5/historical/r6i1p...             NaN
# 3889   gs://cmip6/CMIP/CCCma/CanESM5/historical/r7i1p...             NaN
# ...                                                  ...             ...
# 8713   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 8793   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 8873   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 8953   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9033   gs://cmip6/CMIP/IPSL/IPSL-CM6A-LR/historical/r...             NaN
# 9262   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r1...             NaN
# 9330   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r2...             NaN
# 9398   gs://cmip6/CMIP/MIROC/MIROC-ES2L/historical/r3...             NaN
# 22237  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22313  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22737  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 22800  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r1...             NaN
# 23103  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r2...             NaN
# 23165  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r2...             NaN
# 23228  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r3...             NaN
# 23290  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r3...             NaN
# 23353  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r4...             NaN
# 23415  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r4...             NaN
# 23479  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r5...             NaN
# 23542  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r5...             NaN
# 23606  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23668  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23732  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23794  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23857  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23920  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23984  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24047  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 26201  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26377  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
#
# [92 rows x 10 columns]

# %% [markdown]
# ### Loading data
#
# `intake-esm` enables loading data directly into an [xarray.Dataset](http://xarray.pydata.org/en/stable/api.html#dataset).
#
# Note that data on the cloud are in
# [zarr](https://zarr.readthedocs.io/en/stable/) and data on
# [glade](https://www2.cisl.ucar.edu/resources/storage-and-file-systems/glade-file-spaces) are stored as
# [netCDF](https://www.unidata.ucar.edu/software/netcdf/) files. This is opaque to the user.
#
# `intake-esm` has rules for aggegating datasets; these rules are defined in the collection-specification file.

# %%
dset_dict = cat.to_dataset_dict(zarr_kwargs={'consolidated': True, 'decode_times': False}, 
                                cdf_kwargs={'chunks': {}, 'decode_times': False})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 6 group(s)

# %% [markdown]
# `dset_dict` is a dictionary of `xarray.Dataset`'s; its keys are constructed to refer to compatible groups.

# %%
dset_dict.keys()
# Out:
# dict_keys(['CMIP.CCCma.CanESM5.historical.Oyr.gn', 'CMIP.IPSL.IPSL-CM6A-LR.historical.Oyr.gn', 'CMIP.MIROC.MIROC-ES2L.historical.Oyr.gn', 'ScenarioMIP.CCCma.CanESM5.ssp585.Oyr.gn', 'ScenarioMIP.IPSL.IPSL-CM6A-LR.ssp585.Oyr.gn', 'ScenarioMIP.MIROC.MIROC-ES2L.ssp585.Oyr.gn'])

# %% [markdown]
# We can access a particular dataset as follows.

# %%
dset_dict['CMIP.CCCma.CanESM5.historical.Oyr.gn']
# Out:
# <xarray.Dataset>
# Dimensions:             (bnds: 2, i: 360, j: 291, lev: 45, member_id: 35, time: 165, vertices: 4)
# Coordinates:
#   * j                   (j) int32 0 1 2 3 4 5 6 ... 284 285 286 287 288 289 290
#   * time                (time) float64 182.5 547.5 912.5 ... 5.968e+04 6.004e+04
#   * i                   (i) int32 0 1 2 3 4 5 6 ... 353 354 355 356 357 358 359
#   * lev                 (lev) float64 3.047 9.454 16.36 ... 5.375e+03 5.625e+03
#   * member_id           (member_id) <U9 'r10i1p1f1' 'r10i1p2f1' ... 'r9i1p2f1'
# Dimensions without coordinates: bnds, vertices
# Data variables:
#     lev_bnds            (lev, bnds) float64 dask.array<chunksize=(45, 2), meta=np.ndarray>
#     latitude            (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     time_bnds           (time, bnds) float64 dask.array<chunksize=(165, 2), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     longitude           (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     o2                  (member_id, time, lev, j, i) float32 dask.array<chunksize=(1, 12, 45, 291, 360), meta=np.ndarray>
# Attributes:
#     source_type:                 AOGCM
#     experiment_id:               historical
#     product:                     model-output
#     source_id:                   CanESM5
#     version:                     v20190429
#     branch_time_in_parent:       1496500.0
#     realm:                       ocnBgchem
#     contact:                     ec.cccma.info-info.ccmac.ec@canada.ca
#     CCCma_parent_runid:          p2-pictrl
#     creation_date:               2019-05-30T08:58:45Z
#     external_variables:          areacello volcello
#     license:                     CMIP6 model data produced by The Government ...
#     grid:                        ORCA1 tripolar grid, 1 deg with refinement t...
#     CCCma_model_hash:            Unknown
#     mip_era:                     CMIP6
#     parent_experiment_id:        piControl
#     nominal_resolution:          100 km
#     parent_time_units:           days since 1850-01-01 0:0:0.0
#     variant_label:               r9i1p2f1
#     institution_id:              CCCma
#     branch_method:               Spin-up documentation
#     Conventions:                 CF-1.7 CMIP-6.2
#     references:                  Geophysical Model Development Special issue ...
#     branch_time_in_child:        0.0
#     YMDH_branch_time_in_child:   1850:01:01:00
#     sub_experiment_id:           none
#     table_id:                    Oyr
#     grid_label:                  gn
#     data_specs_version:          01.00.29
#     initialization_index:        1
#     frequency:                   yr
#     parent_activity_id:          CMIP
#     history:                     2019-05-02T13:53:53Z ;rewrote data to be con...
#     experiment:                  all-forcing simulation of the recent past
#     table_info:                  Creation Date:(20 February 2019) MD5:374fbe5...
#     parent_mip_era:              CMIP6
#     source:                      CanESM5 (2019): \naerosol: interactive\natmo...
#     activity_id:                 CMIP
#     CCCma_runid:                 p2-his09
#     parent_source_id:            CanESM5
#     institution:                 Canadian Centre for Climate Modelling and An...
#     realization_index:           9
#     title:                       CanESM5 output prepared for CMIP6
#     YMDH_branch_time_in_parent:  5950:01:01:00
#     tracking_id:                 hdl:21.14100/41426118-701c-482b-ae16-82932e4...
#     cmor_version:                3.4.0
#     further_info_url:            https://furtherinfo.es-doc.org/CMIP6.CCCma.C...
#     sub_experiment:              none
#     forcing_index:               1
#     variable_id:                 o2

# %% [markdown]
# ### More advanced queries
#
# As motivation for diving into more advanced manipulations with `intake-esm`, let's consider the task of getting access to grid information in the `Ofx` table_id.

# %%
cat_fx = col.search(experiment_id=['historical', 'ssp585'], source_id=models, table_id='Ofx', grid_label='gn')
cat_fx.df
# Out:
#        activity_id institution_id     source_id experiment_id  member_id  \
# 1435          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1436          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1437          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1438          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1535          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1536          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1537          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1538          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1605          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1606          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1607          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1608          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1645          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1646          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1647          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1648          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1701          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1702          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1703          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1704          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1741          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1742          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1743          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1744          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1797          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1798          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1799          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1800          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1838          CMIP          CCCma       CanESM5    historical  r13i1p2f1
# 1839          CMIP          CCCma       CanESM5    historical  r13i1p2f1
# ...            ...            ...           ...           ...        ...
# 23663  ScenarioMIP          CCCma       CanESM5        ssp585   r6i1p2f1
# 23724  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23725  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23726  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23727  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23786  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23787  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23788  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23789  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23849  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23850  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23851  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23852  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23911  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23912  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23913  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23914  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23975  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23976  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23977  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23978  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 24039  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24040  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24041  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24042  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 26167  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26168  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26355  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
# 26356  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
# 26357  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
#
#       table_id variable_id grid_label  \
# 1435       Ofx   areacello         gn
# 1436       Ofx      deptho         gn
# 1437       Ofx       sftof         gn
# 1438       Ofx    thkcello         gn
# 1535       Ofx   areacello         gn
# 1536       Ofx      deptho         gn
# 1537       Ofx       sftof         gn
# 1538       Ofx    thkcello         gn
# 1605       Ofx   areacello         gn
# 1606       Ofx      deptho         gn
# 1607       Ofx       sftof         gn
# 1608       Ofx    thkcello         gn
# 1645       Ofx   areacello         gn
# 1646       Ofx      deptho         gn
# 1647       Ofx       sftof         gn
# 1648       Ofx    thkcello         gn
# 1701       Ofx   areacello         gn
# 1702       Ofx      deptho         gn
# 1703       Ofx       sftof         gn
# 1704       Ofx    thkcello         gn
# 1741       Ofx   areacello         gn
# 1742       Ofx      deptho         gn
# 1743       Ofx       sftof         gn
# 1744       Ofx    thkcello         gn
# 1797       Ofx   areacello         gn
# 1798       Ofx      deptho         gn
# 1799       Ofx       sftof         gn
# 1800       Ofx    thkcello         gn
# 1838       Ofx   areacello         gn
# 1839       Ofx      deptho         gn
# ...        ...         ...        ...
# 23663      Ofx    thkcello         gn
# 23724      Ofx   areacello         gn
# 23725      Ofx      deptho         gn
# 23726      Ofx       sftof         gn
# 23727      Ofx    thkcello         gn
# 23786      Ofx   areacello         gn
# 23787      Ofx      deptho         gn
# 23788      Ofx       sftof         gn
# 23789      Ofx    thkcello         gn
# 23849      Ofx   areacello         gn
# 23850      Ofx      deptho         gn
# 23851      Ofx       sftof         gn
# 23852      Ofx    thkcello         gn
# 23911      Ofx   areacello         gn
# 23912      Ofx      deptho         gn
# 23913      Ofx       sftof         gn
# 23914      Ofx    thkcello         gn
# 23975      Ofx   areacello         gn
# 23976      Ofx      deptho         gn
# 23977      Ofx       sftof         gn
# 23978      Ofx    thkcello         gn
# 24039      Ofx   areacello         gn
# 24040      Ofx      deptho         gn
# 24041      Ofx       sftof         gn
# 24042      Ofx    thkcello         gn
# 26167      Ofx   areacello         gn
# 26168      Ofx       basin         gn
# 26355      Ofx   areacello         gn
# 26356      Ofx      deptho         gn
# 26357      Ofx       sftof         gn
#
#                                                   zstore  dcpp_init_year
# 1435   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1436   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1437   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1438   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1535   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1536   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1537   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1538   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1605   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1606   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1607   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1608   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1645   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1646   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1647   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1648   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1701   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1702   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1703   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1704   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1741   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1742   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1743   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1744   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1797   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1798   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1799   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1800   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1838   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1839   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# ...                                                  ...             ...
# 23663  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23724  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23725  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23726  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23727  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23786  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23787  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23788  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23789  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23849  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23850  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23851  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23852  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23911  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23912  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23913  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23914  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23975  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23976  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23977  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23978  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24039  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24040  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24041  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24042  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 26167  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26168  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26355  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 26356  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 26357  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
#
# [418 rows x 10 columns]

# %% [markdown]
# This, however, comes with lots of redundant information.
#
# Additionally, it may be necessary to do more targeted manipulations of the search. For instance, we've found a handful of corrupted files on `glade` and might need to work around loading these.
#
# As an illustration of this, in the code below, we specify a list of to queries (in this case one) to eliminate.

# %%
import numpy as np

# specify a list of queries to eliminate
corrupt_data = [dict(variable_id='areacello', source_id='IPSL-CM6A-LR',
                     experiment_id='historical', member_id='r2i1p1f1')
               ]


# copy the dataframe 
df = cat_fx.df.copy()

# eliminate data
for elim in corrupt_data:
    condition = np.ones(len(df), dtype=bool)
    for key, val in elim.items():
        condition = condition & (df[key] == val)
    df = df.loc[~condition]
df
# Out:
#        activity_id institution_id     source_id experiment_id  member_id  \
# 1435          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1436          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1437          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1438          CMIP          CCCma       CanESM5    historical  r10i1p1f1
# 1535          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1536          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1537          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1538          CMIP          CCCma       CanESM5    historical  r10i1p2f1
# 1605          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1606          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1607          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1608          CMIP          CCCma       CanESM5    historical  r11i1p1f1
# 1645          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1646          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1647          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1648          CMIP          CCCma       CanESM5    historical  r11i1p2f1
# 1701          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1702          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1703          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1704          CMIP          CCCma       CanESM5    historical  r12i1p1f1
# 1741          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1742          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1743          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1744          CMIP          CCCma       CanESM5    historical  r12i1p2f1
# 1797          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1798          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1799          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1800          CMIP          CCCma       CanESM5    historical  r13i1p1f1
# 1838          CMIP          CCCma       CanESM5    historical  r13i1p2f1
# 1839          CMIP          CCCma       CanESM5    historical  r13i1p2f1
# ...            ...            ...           ...           ...        ...
# 23663  ScenarioMIP          CCCma       CanESM5        ssp585   r6i1p2f1
# 23724  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23725  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23726  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23727  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p1f1
# 23786  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23787  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23788  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23789  ScenarioMIP          CCCma       CanESM5        ssp585   r7i1p2f1
# 23849  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23850  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23851  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23852  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p1f1
# 23911  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23912  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23913  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23914  ScenarioMIP          CCCma       CanESM5        ssp585   r8i1p2f1
# 23975  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23976  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23977  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 23978  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p1f1
# 24039  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24040  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24041  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 24042  ScenarioMIP          CCCma       CanESM5        ssp585   r9i1p2f1
# 26167  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26168  ScenarioMIP           IPSL  IPSL-CM6A-LR        ssp585   r1i1p1f1
# 26355  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
# 26356  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
# 26357  ScenarioMIP          MIROC    MIROC-ES2L        ssp585   r1i1p1f2
#
#       table_id variable_id grid_label  \
# 1435       Ofx   areacello         gn
# 1436       Ofx      deptho         gn
# 1437       Ofx       sftof         gn
# 1438       Ofx    thkcello         gn
# 1535       Ofx   areacello         gn
# 1536       Ofx      deptho         gn
# 1537       Ofx       sftof         gn
# 1538       Ofx    thkcello         gn
# 1605       Ofx   areacello         gn
# 1606       Ofx      deptho         gn
# 1607       Ofx       sftof         gn
# 1608       Ofx    thkcello         gn
# 1645       Ofx   areacello         gn
# 1646       Ofx      deptho         gn
# 1647       Ofx       sftof         gn
# 1648       Ofx    thkcello         gn
# 1701       Ofx   areacello         gn
# 1702       Ofx      deptho         gn
# 1703       Ofx       sftof         gn
# 1704       Ofx    thkcello         gn
# 1741       Ofx   areacello         gn
# 1742       Ofx      deptho         gn
# 1743       Ofx       sftof         gn
# 1744       Ofx    thkcello         gn
# 1797       Ofx   areacello         gn
# 1798       Ofx      deptho         gn
# 1799       Ofx       sftof         gn
# 1800       Ofx    thkcello         gn
# 1838       Ofx   areacello         gn
# 1839       Ofx      deptho         gn
# ...        ...         ...        ...
# 23663      Ofx    thkcello         gn
# 23724      Ofx   areacello         gn
# 23725      Ofx      deptho         gn
# 23726      Ofx       sftof         gn
# 23727      Ofx    thkcello         gn
# 23786      Ofx   areacello         gn
# 23787      Ofx      deptho         gn
# 23788      Ofx       sftof         gn
# 23789      Ofx    thkcello         gn
# 23849      Ofx   areacello         gn
# 23850      Ofx      deptho         gn
# 23851      Ofx       sftof         gn
# 23852      Ofx    thkcello         gn
# 23911      Ofx   areacello         gn
# 23912      Ofx      deptho         gn
# 23913      Ofx       sftof         gn
# 23914      Ofx    thkcello         gn
# 23975      Ofx   areacello         gn
# 23976      Ofx      deptho         gn
# 23977      Ofx       sftof         gn
# 23978      Ofx    thkcello         gn
# 24039      Ofx   areacello         gn
# 24040      Ofx      deptho         gn
# 24041      Ofx       sftof         gn
# 24042      Ofx    thkcello         gn
# 26167      Ofx   areacello         gn
# 26168      Ofx       basin         gn
# 26355      Ofx   areacello         gn
# 26356      Ofx      deptho         gn
# 26357      Ofx       sftof         gn
#
#                                                   zstore  dcpp_init_year
# 1435   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1436   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1437   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1438   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1535   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1536   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1537   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1538   gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN
# 1605   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1606   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1607   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1608   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1645   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1646   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1647   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1648   gs://cmip6/CMIP/CCCma/CanESM5/historical/r11i1...             NaN
# 1701   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1702   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1703   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1704   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1741   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1742   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1743   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1744   gs://cmip6/CMIP/CCCma/CanESM5/historical/r12i1...             NaN
# 1797   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1798   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1799   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1800   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1838   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# 1839   gs://cmip6/CMIP/CCCma/CanESM5/historical/r13i1...             NaN
# ...                                                  ...             ...
# 23663  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r6...             NaN
# 23724  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23725  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23726  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23727  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23786  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23787  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23788  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23789  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r7...             NaN
# 23849  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23850  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23851  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23852  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23911  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23912  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23913  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23914  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r8...             NaN
# 23975  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23976  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23977  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 23978  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24039  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24040  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24041  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 24042  gs://cmip6/ScenarioMIP/CCCma/CanESM5/ssp585/r9...             NaN
# 26167  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26168  gs://cmip6/ScenarioMIP/IPSL/IPSL-CM6A-LR/ssp58...             NaN
# 26355  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 26356  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 26357  gs://cmip6/ScenarioMIP/MIROC/MIROC-ES2L/ssp585...             NaN
#
# [417 rows x 10 columns]

# %% [markdown]
# We then drop duplicates.

# %%
df.drop_duplicates(subset=['source_id', 'variable_id'], inplace=True)

# %% [markdown]
# Now, since we've only retained one ensemble member, we need to eliminate that column. If we omit this step, `intake-esm` will throw an error, complaining that different variables are present for each ensemble member. Setting the `member_id` column to NaN precludes attempts to join along the ensemble dimension.
#
# After this final manipulation, we copy the `DataFrame` back to the collection object and procede with loading the data.

# %%
df['member_id'] = np.nan
cat_fx.df = df

# %%
fx_dsets = cat_fx.to_dataset_dict(zarr_kwargs={'consolidated': True}, cdf_kwargs={'chunks': {}})
# Out:
# --> The keys in the returned dictionary of datasets are constructed as follows:
# 	'activity_id.institution_id.source_id.experiment_id.table_id.grid_label'
#
# --> There will be 3 group(s)

# %%
fx_dsets.keys()
# Out:
# dict_keys(['CMIP.CCCma.CanESM5.historical.Ofx.gn', 'CMIP.IPSL.IPSL-CM6A-LR.historical.Ofx.gn', 'CMIP.MIROC.MIROC-ES2L.historical.Ofx.gn'])

# %%
for key, ds in fx_dsets.items():
    print(ds.data_vars)
# Out:
# Data variables:
#     areacello           (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     latitude            (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     longitude           (j, i) float64 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     vertices_latitude   (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     vertices_longitude  (j, i, vertices) float64 dask.array<chunksize=(291, 360, 4), meta=np.ndarray>
#     deptho              (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     sftof               (j, i) float32 dask.array<chunksize=(291, 360), meta=np.ndarray>
#     type                |S3 ...
#     lev_bnds            (lev, bnds) float64 dask.array<chunksize=(45, 2), meta=np.ndarray>
#     thkcello            (lev, j, i) float32 dask.array<chunksize=(45, 291, 360), meta=np.ndarray>
# Data variables:
#     area            (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     areacello       (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     bounds_nav_lat  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     bounds_nav_lon  (y, x, nvertex) float32 dask.array<chunksize=(332, 362, 4), meta=np.ndarray>
#     nav_lat         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     nav_lon         (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
#     basin           (y, x) float32 dask.array<chunksize=(332, 362), meta=np.ndarray>
# Data variables:
#     areacello           (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     latitude            (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     longitude           (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     vertices_latitude   (y, x, vertices) float32 dask.array<chunksize=(256, 360, 4), meta=np.ndarray>
#     vertices_longitude  (y, x, vertices) float32 dask.array<chunksize=(256, 360, 4), meta=np.ndarray>
#     x_bnds              (x, bnds) float64 dask.array<chunksize=(360, 2), meta=np.ndarray>
#     y_bnds              (y, bnds) float64 dask.array<chunksize=(256, 2), meta=np.ndarray>
#     deptho              (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     sftof               (y, x) float32 dask.array<chunksize=(256, 360), meta=np.ndarray>
#     type                |S3 ...

# %% [markdown]
# ## Demonstrate how spin-up a dask cluster
#
# If you expect to require Big Data capabilities, here's how you spin up a [dask](https://dask.org) cluster using [dask-jobqueue](https://dask-jobqueue.readthedocs.io/en/latest/).
#
# The syntax is different if on an NCAR machine versus the cloud.

# %%
if util.is_ncar_host():
    from ncar_jobqueue import NCARCluster
    cluster = NCARCluster(project='UCGD0006')
    cluster.adapt(minimum_jobs=1, maximum_jobs=10)
else:
    from dask_kubernetes import KubeCluster
    cluster = KubeCluster()
    cluster.adapt(minimum=1, maximum=10)
cluster
# Out:
# VBox(children=(HTML(value='<h2>KubeCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    .…

# %%
from dask.distributed import Client
client = Client(cluster) # Connect this local process to remote workers
client
# Out:
# <Client: 'tcp://10.32.15.21:43305' processes=1 threads=2, memory=11.50 GB>
