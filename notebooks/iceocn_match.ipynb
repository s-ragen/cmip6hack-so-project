# %%
import numpy as np
import xarray as xr
import intake
import gcsfs
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/intake/source/discovery.py:136: FutureWarning: The drivers ['stac-catalog', 'stac-collection', 'stac-item'] do not specify entry_points and were only discovered via a package scan. This may break in a future release of intake. The packages should be updated.
#   FutureWarning)

# %%
url = "https://raw.githubusercontent.com/andrewpauling/cmip6hack-so-project/master/catalogs/pangeo-cmip6.json"
col = intake.open_esm_datastore(url)
col.df.head()
# Out:
#   activity_id institution_id source_id experiment_id member_id table_id  \
# 0  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 1  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 2  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 3  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
# 4  AerChemMIP            BCC  BCC-ESM1        ssp370  r1i1p1f1     Amon
#
#   variable_id grid_label                                             zstore  \
# 0          pr         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 1        prsn         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 2         tas         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 3      tasmax         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
# 4      tasmin         gn  gs://cmip6/AerChemMIP/BCC/BCC-ESM1/ssp370/r1i1...
#
#    dcpp_init_year
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
cat = col.search(experiment_id=['historical'], table_id=['SImon', 'Omon'],
                 grid_label='gn')
cat.df.head()
# Out:
#     activity_id institution_id      source_id experiment_id member_id  \
# 163        CMIP            AWI  AWI-CM-1-1-MR    historical  r1i1p1f1
# 164        CMIP            AWI  AWI-CM-1-1-MR    historical  r1i1p1f1
# 165        CMIP            AWI  AWI-CM-1-1-MR    historical  r1i1p1f1
# 166        CMIP            AWI  AWI-CM-1-1-MR    historical  r1i1p1f1
# 167        CMIP            AWI  AWI-CM-1-1-MR    historical  r1i1p1f1
#
#     table_id variable_id grid_label  \
# 163     Omon        hfds         gn
# 164     Omon      mlotst         gn
# 165     Omon          so         gn
# 166     Omon         sos         gn
# 167     Omon       tauuo         gn
#
#                                                 zstore  dcpp_init_year
# 163  gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/historical/r...             NaN
# 164  gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/historical/r...             NaN
# 165  gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/historical/r...             NaN
# 166  gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/historical/r...             NaN
# 167  gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/historical/r...             NaN

# %%
import pprint 
uni_dict = col.unique(['source_id', 'experiment_id', 'table_id'])
pprint.pprint(uni_dict, compact=True)
# Out:
# {'experiment_id': {'count': 29,
#                    'values': ['ssp370', 'esm-ssp585', '1pctCO2-bgc', 'hist-bgc',
#                               '1pctCO2', 'abrupt-4xCO2', 'historical',
#                               'piControl', 'amip', 'esm-hist', 'esm-piControl',
#                               'hist-GHG', 'hist-aer', 'hist-nat', 'dcppA-assim',
#                               'dcppA-hindcast', 'dcppC-hindcast-noAgung',
#                               'dcppC-hindcast-noElChichon',
#                               'dcppC-hindcast-noPinatubo', 'highresSST-present',
#                               'control-1950', 'hist-1950', 'deforest-globe',
#                               'esm-ssp585-ssp126Lu', 'omip1', 'lgm', 'ssp126',
#                               'ssp245', 'ssp585']},
#  'source_id': {'count': 48,
#                'values': ['BCC-ESM1', 'BCC-CSM2-MR', 'CanESM5', 'CNRM-ESM2-1',
#                           'UKESM1-0-LL', 'GISS-E2-1-G', 'CESM2', 'GFDL-ESM4',
#                           'AWI-CM-1-1-MR', 'CAMS-CSM1-0', 'FGOALS-f3-L',
#                           'FGOALS-g3', 'CNRM-CM6-1', 'E3SM-1-0', 'EC-Earth3-LR',
#                           'EC-Earth3-Veg', 'EC-Earth3', 'FIO-ESM-2-0',
#                           'IPSL-CM6A-LR', 'MIROC-ES2L', 'MIROC6',
#                           'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM', 'MRI-ESM2-0',
#                           'GISS-E2-1-G-CC', 'GISS-E2-1-H', 'CESM2-WACCM',
#                           'NorCPM1', 'GFDL-AM4', 'GFDL-CM4', 'NESM3',
#                           'SAM0-UNICON', 'MCM-UA-1-0', 'CMCC-CM2-HR4',
#                           'CMCC-CM2-VHR4', 'CNRM-CM6-1-HR', 'ECMWF-IFS-HR',
#                           'ECMWF-IFS-LR', 'IPSL-CM6A-ATM-HR', 'NICAM16-7S',
#                           'NICAM16-8S', 'NICAM16-9S', 'HadGEM3-GC31-HM',
#                           'HadGEM3-GC31-LM', 'MRI-AGCM3-2-H', 'MRI-AGCM3-2-S',
#                           'GFDL-CM4C192', 'MPI-ESM1-2-HR']},
#  'table_id': {'count': 23,
#               'values': ['Amon', 'Lmon', 'Oyr', 'Omon', 'SImon', 'day', '3hr',
#                          '6hrLev', 'LImon', 'Aclim', 'Ofx', 'fx', 'Emon',
#                          '6hrPlev', 'Oclim', 'SIclim', 'Eclim', 'Odec',
#                          'AERmon', 'ImonGre', '6hrPlevPt', 'CF3hr', 'E3hr']}}

# %% [markdown]
# Find all the models that have monthly siconc and monthly thetao and so

# %%
cat = col.search(experiment_id=['historical'], table_id=['SImon', 'Omon'],
                 grid_label='gn', variable_id=['siconc', 'thetao', 'so'])
cat.df.head()
# Out:
#     activity_id institution_id      source_id experiment_id member_id  \
# 165        CMIP            AWI  AWI-CM-1-1-MR    historical  r1i1p1f1
# 169        CMIP            AWI  AWI-CM-1-1-MR    historical  r1i1p1f1
# 323        CMIP            BCC    BCC-CSM2-MR    historical  r1i1p1f1
# 325        CMIP            BCC    BCC-CSM2-MR    historical  r1i1p1f1
# 586        CMIP            BCC       BCC-ESM1    historical  r1i1p1f1
#
#     table_id variable_id grid_label  \
# 165     Omon          so         gn
# 169     Omon      thetao         gn
# 323     Omon          so         gn
# 325     Omon      thetao         gn
# 586     Omon          so         gn
#
#                                                 zstore  dcpp_init_year
# 165  gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/historical/r...             NaN
# 169  gs://cmip6/CMIP/AWI/AWI-CM-1-1-MR/historical/r...             NaN
# 323  gs://cmip6/CMIP/BCC/BCC-CSM2-MR/historical/r1i...             NaN
# 325  gs://cmip6/CMIP/BCC/BCC-CSM2-MR/historical/r1i...             NaN
# 586  gs://cmip6/CMIP/BCC/BCC-ESM1/historical/r1i1p1...             NaN

# %% [markdown]
# # Get models that have monthly sea ice concentration, thetao and so

# %%
models = set(uni_dict['source_id']['values']) # all the models

for table_id in ['SImon', 'Omon']:
    if table_id == 'SImon':
        query = dict(experiment_id='historical', table_id=table_id, 
                     variable_id='siconc', grid_label='gn')  
        cat = col.search(**query)
        models = models.intersection({model for model in cat.df.source_id.unique().tolist()})
    else:
        for variable_id in ['thetao', 'so']:
            query = dict(experiment_id='historical', table_id=table_id, 
                         variable_id=variable_id, grid_label='gn')  
            cat = col.search(**query)
            models = models.intersection({model for model in cat.df.source_id.unique().tolist()})
        

models = list(models)
models
# Out:
# ['GFDL-CM4',
#  'SAM0-UNICON',
#  'CESM2',
#  'MIROC6',
#  'CanESM5',
#  'MIROC-ES2L',
#  'CNRM-CM6-1',
#  'CAMS-CSM1-0',
#  'IPSL-CM6A-LR',
#  'EC-Earth3-Veg',
#  'CNRM-ESM2-1',
#  'NESM3',
#  'UKESM1-0-LL',
#  'HadGEM3-GC31-LL']

# %%
cat = col.search(experiment_id='historical', table_id=['Omon', 'SImon'], 
                 variable_id=['siconc', 'thetao', 'so'], grid_label='gn', source_id=models)
cat.df.head()
# Out:
#      activity_id institution_id    source_id experiment_id  member_id  \
# 838         CMIP           CAMS  CAMS-CSM1-0    historical   r1i1p1f1
# 841         CMIP           CAMS  CAMS-CSM1-0    historical   r1i1p1f1
# 847         CMIP           CAMS  CAMS-CSM1-0    historical   r1i1p1f1
# 863         CMIP           CAMS  CAMS-CSM1-0    historical   r2i1p1f1
# 1455        CMIP          CCCma      CanESM5    historical  r10i1p1f1
#
#      table_id variable_id grid_label  \
# 838      Omon          so         gn
# 841      Omon      thetao         gn
# 847     SImon      siconc         gn
# 863     SImon      siconc         gn
# 1455     Omon          so         gn
#
#                                                  zstore  dcpp_init_year
# 838   gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/historical/r1...             NaN
# 841   gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/historical/r1...             NaN
# 847   gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/historical/r1...             NaN
# 863   gs://cmip6/CMIP/CAMS/CAMS-CSM1-0/historical/r2...             NaN
# 1455  gs://cmip6/CMIP/CCCma/CanESM5/historical/r10i1...             NaN

# %% [markdown]
# # Make sure each entry has the same ensemble member

# %%
members = set(uni_dict['member_id']['values']) # all the ensemble members

for model in models:
    tmp = cat.search(source_id=model)
    for member in tmp.df['member_id']:
        query = dict(experiment_id='historical', table_id=table_id, 
                     variable_id='siconc', grid_label='gn')  
        cat = col.search(**query)
        members = members.intersection({m for model in cat.df.source_id.unique().tolist()})
        
    
tmp.df.head()
# Out:
#       activity_id institution_id        source_id experiment_id member_id  \
# 10136        CMIP           MOHC  HadGEM3-GC31-LL    historical  r1i1p1f3
# 10200        CMIP           MOHC  HadGEM3-GC31-LL    historical  r2i1p1f3
# 10204        CMIP           MOHC  HadGEM3-GC31-LL    historical  r2i1p1f3
# 10217        CMIP           MOHC  HadGEM3-GC31-LL    historical  r2i1p1f3
# 10260        CMIP           MOHC  HadGEM3-GC31-LL    historical  r3i1p1f3
#
#       table_id variable_id grid_label  \
# 10136    SImon      siconc         gn
# 10200     Omon          so         gn
# 10204     Omon      thetao         gn
# 10217    SImon      siconc         gn
# 10260    SImon      siconc         gn
#
#                                                   zstore  dcpp_init_year
# 10136  gs://cmip6/CMIP/MOHC/HadGEM3-GC31-LL/historica...             NaN
# 10200  gs://cmip6/CMIP/MOHC/HadGEM3-GC31-LL/historica...             NaN
# 10204  gs://cmip6/CMIP/MOHC/HadGEM3-GC31-LL/historica...             NaN
# 10217  gs://cmip6/CMIP/MOHC/HadGEM3-GC31-LL/historica...             NaN
# 10260  gs://cmip6/CMIP/MOHC/HadGEM3-GC31-LL/historica...             NaN

# %%
filt_dict = dict()

for model in models:
    tmp2 = cat.search(source_id=model)
    tmp2.df.head()
    members = tmp2.df['member_id']
    memlist = list()
    for member in list(members):
        a = tmp2.search(member_id=member, variable_id='siconc').df['activity_id'].empty
        b = tmp2.search(member_id=member, variable_id='thetao').df['activity_id'].empty
        c = tmp2.search(member_id=member, variable_id='so').df['activity_id'].empty
        if not a and not b and not c and member not in memlist:
            memlist.append(member)
    filt_dict[model] =  memlist

# %%
filt_dict
# Out:
# {'GFDL-CM4': ['r1i1p1f1'],
#  'SAM0-UNICON': ['r1i1p1f1'],
#  'CESM2': ['r10i1p1f1',
#   'r11i1p1f1',
#   'r1i1p1f1',
#   'r2i1p1f1',
#   'r3i1p1f1',
#   'r4i1p1f1',
#   'r5i1p1f1',
#   'r6i1p1f1',
#   'r7i1p1f1',
#   'r8i1p1f1',
#   'r9i1p1f1'],
#  'MIROC6': ['r10i1p1f1'],
#  'CanESM5': ['r10i1p1f1'],
#  'MIROC-ES2L': ['r1i1p1f2'],
#  'CNRM-CM6-1': ['r10i1p1f2'],
#  'CAMS-CSM1-0': ['r1i1p1f1'],
#  'IPSL-CM6A-LR': ['r10i1p1f1'],
#  'EC-Earth3-Veg': ['r1i1p1f1'],
#  'CNRM-ESM2-1': ['r2i1p1f2'],
#  'NESM3': ['r1i1p1f1'],
#  'UKESM1-0-LL': ['r1i1p1f2'],
#  'HadGEM3-GC31-LL': ['r2i1p1f3']}
